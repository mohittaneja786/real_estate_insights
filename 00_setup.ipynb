# %%
df = (
spark.sql("CREATE	CATALOG	IF	NOT	EXISTS	real_estate_dev"),
spark.sql("CREATE	SCHEMA	IF	NOT	EXISTS	real_estate_dev.bronze"),
spark.sql("CREATE	SCHEMA	IF	NOT	EXISTS	real_estate_dev.silver"),
spark.sql("CREATE	SCHEMA	IF	NOT	EXISTS	real_estate_dev.gold"),
spark.sql("CREATE	VOLUME	IF	NOT	EXISTS	real_estate_dev.bronze.vl_real_estate")

)
